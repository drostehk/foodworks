# %%
# -*- coding: utf-8 -*-
from __future__ import unicode_literals, division

import IPython
import warnings
from datetime import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

from IPython.display import HTML
from IPython.display import display as prnt

import sys
reload(sys)
sys.setdefaultencoding("utf-8")

# Notebook Options
# %matplotlib inline
warnings.filterwarnings('ignore')
np.set_printoptions(suppress=True)

# Matplotlib Styles
c = {
'axes.labelsize': 17,
'axes.titlesize': 16,
'figure.figsize': [18, 8],
'grid.linewidth': 1.6,
'legend.fontsize': 17,
'lines.linewidth': 2,
'lines.markeredgewidth': 0.0,
'lines.markersize': 11,
'patch.linewidth': 0.5,
'xtick.labelsize': 16,
'xtick.major.pad': 20,
'xtick.major.width': 2,
'xtick.minor.width': 1,
'ytick.labelsize': 16.0,
'ytick.major.pad': 20,
'ytick.major.width': 2,
'ytick.minor.width': 1 }

wide_c = dict(c, **{'figure.figsize':[20,8]})

sns.set_style("whitegrid")

# Darken of Lighten a Colour

def color_variant(rgba_color, brightness_offset=1):
    """ takes a colour like (1,0.7,0.3,1) and produces a lighter or darker variant """
    if len(rgba_color) != 4:
        raise Exception("Passed %s into color_variant(), needs to be in (1,0.7,0.3,1) format." % rgba_color)
    new_rgb_int = [rgba_value + brightness_offset/255 for rgba_value in rgba_color[:3]]
    new_rgb_int = [min([1, max([0, i])]) for i in new_rgb_int] # make sure new values are between 0 and 1
    new_rgb_int.append(rgba_color[3])
    return new_rgb_int

# Colours

blue = (118,202,255)
lime = (2,255,179) 
green = (40,255,3)
orange = (255,195,0)
red = (255,83,64) 
purple = (255,92,212)

rgb_frac = lambda rgb: [c / 255 for c in rgb]

# sns.palplot(sns.blend_palette([rgb_frac(blue),rgb_frac(lime),rgb_frac(green)], n_colors=15),size=1)
cm_fresh = lambda n: sns.blend_palette([rgb_frac(green),rgb_frac(lime),rgb_frac(blue)], n_colors=n)
# sns.palplot(sns.blend_palette([rgb_frac(orange),rgb_frac(red),rgb_frac(purple)], n_colors=15),size=1)
cm_packaged = lambda n: sns.blend_palette([rgb_frac(orange),rgb_frac(red),rgb_frac(purple)], n_colors=n)

# Utility Functions
def table(df, replace_match="",replace_str="", print_index=True, print_header=True):
    return IPython.display.display(HTML(df.to_html(index=print_index, header=print_header).replace('<table border="1" class="dataframe">','<table class="table table-striped table-hover">').replace(replace_match,replace_str)))

# HTML Functions
h1 = lambda x : prnt(HTML('''<h1 style="text-align:center">'''+ x +'''</h1>'''))
h2 = lambda x: prnt(HTML('''<h2 style="text-align:center">'''+ x +'''</h2>'''))
h2_success = lambda x: prnt(HTML('''<h2 style="text-align:center" class="alert alert-success">'''+ x +'''</h2>'''))

h3_danger = lambda x: prnt(HTML('''<h3 style="text-align:center" class="alert alert-danger">'''+ x +'''</h3>'''))
h3_info = lambda x: prnt(HTML('''<h3 style="text-align:center" class="alert alert-info">'''+ x +'''</h3>'''))
h3_warning = lambda x: prnt(HTML('''<h3 style="text-align:center" class="alert alert-warning">'''+ x +'''</h3>'''))

h3 = lambda x : prnt(HTML('''<h3 style="text-align:center">'''+ x +'''</h3>'''))
p  = lambda x : prnt(HTML('''<p class="text_cell_render">'''+ x +'''</p>'''))

md_wrap = lambda s, m, e: reduce(lambda x, y: x + "".join(y), zip(s.split(m), ['<'+e+'>','</'+e+'>'] * int(len(s)/2)), "")[:-3] if (m in s) else s
md_b = lambda s : md_wrap(s,'**','b')
md_i = lambda s :  md_wrap(s,'_','i')

md = lambda s : md_i(md_b(s))

def ul(lis):
    lis = ['''<div class="panel panel-default"><div class="panel-body">''' + md(li) + '''</div></div>''' for li in lis]
    prnt(HTML("".join(lis)))
    
# Client Data
org_name = 'Tin Shui Wai Network'
org_code = 'TSWN'
org_uri = '../../Data/Canonical/' + org_code + '/' + org_code
org_data = org_uri + '.csv'
org_i18n = org_uri + '.i18n.csv'
org_map = org_uri + '.map.csv'
org_units = org_uri + '.units.csv'
org_lang = 'zh' # 'en' or 'zh'

# %%
# merge multiple years
df_2014 = pd.read_csv(org_uri+ '.2014.csv')
df_2015 = pd.read_csv(org_uri+ '.2015.csv')
df_combined = df_2014.append(df_2015)
df_combined.to_csv(org_data, index=False)

# %%
h1('FOOD CONNECT | REPORT')
# Out:
# <h1 style="text-align:center">FOOD CONNECT | REPORT</h1>

# %%
h2(org_name)
# Out:
# <h2 style="text-align:center">Tin Shui Wai Network</h2>

# %%
HTML('''<script>

code_show=true;

function code_toggle() {
    if (code_show){ 
        $('div.input').hide();
        $('.output_scroll').removeClass('output_scroll');
        $('.prompt').hide();
    } else {
        $('div.input').show();
        $('.output_scroll').removeClass('output_scroll');
        $('.prompt').show();
    }
    code_show = !code_show
}
</script>
 
<a class='btn btn-warning btn-lg' style="margin:0 auto; display:block; max-width:320px" href="javascript:code_toggle()">TOGGLE CODE</a>''')
# Out:
# <script>
#
# code_show=true;
#
# function code_toggle() {
#     if (code_show){
#         $('div.input').hide();
#         $('.output_scroll').removeClass('output_scroll');
#         $('.prompt').hide();
#     } else {
#         $('div.input').show();
#         $('.output_scroll').removeClass('output_scroll');
#         $('.prompt').show();
#     }
#     code_show = !code_show
# }
# </script>
#
# <a class='btn btn-warning btn-lg' style="margin:0 auto; display:block; max-width:320px" href="javascript:code_toggle()">TOGGLE CODE</a>

# %%
# Data Processing
dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')

df = pd.read_csv(org_data, encoding='utf-8', parse_dates=[0], date_parser=dateparse)  \
        .fillna(0) \
        .set_index(['organisation_id','programme','donor','datetime'])


# Internationalisation
i18n = pd.read_csv(org_i18n, encoding='utf-8')

def is_data_in_lang(df, lang='zh'):
    if df.columns[0] in i18n[lang.upper()].values:
        return True
    else:
        return False

# if org_lang == 'en' and is_data_in_lang(df, 'zh'):
#     df.columns = [i18n.loc[i18n['ZH'] == feat]['EN'].values[0] for feat in df.columns]
# elif org_lang == 'zh' and is_data_in_lang(df, 'en'):
#     df.columns = [i18n.loc[i18n['EN'] == feat]['ZH'].values[0] for feat in df.columns]

# Units
df_units = pd.read_csv(org_units, encoding='utf-8')

# Category Mapping

df_map = pd.read_csv(org_map, encoding='utf-8')

dfg = pd.DataFrame()
for category in df_map.canonical.unique():
    dfg[category] = df[df_map[df_map.canonical == category].category.values].sum(axis=1)

# # TODO : COLOUR CODE CATEGORIES - FRESH vs PACKAGES

# #      : Categorial legend

fresh_categories = ['Leafy Veg', 'Ground Veg', 'Fruit', 'Soy Products', 'Bread', 'Meat', 'Seafood', 'Cooked', 'Fresh Other']
fresh_labels = ['Leafy Veg', 'Ground Veg', 'Fruit', 'Soy Prod.', 'Bread', 'Meat', 'Seafood', 'Cooked', 'Fresh Other']
packaged_categories = ['Staple', 'Frozen', 'Condiment', 'Drinks', 'Milk Powder', 'Packaged Other']
packaged_labels = ['Staple', 'Frozen', 'Condiment', 'Drinks', 'Milk Pow.', 'Pack. Other']


# #      : Float 'Other' Category to the righr.

fresh_cat_count = len([cat for cat in fresh_categories if cat in dfg.columns])
packaged_cat_count = len([cat for cat in packaged_categories if cat in dfg.columns])

label_order = [cat for cat in fresh_categories if cat in dfg.columns] + \
              [cat for cat in packaged_categories if cat in dfg.columns]

dfg = dfg[label_order]

cm = cm_fresh(fresh_cat_count)
cm = np.append(cm, cm_packaged(packaged_cat_count),axis=0)

cm_outline = [color_variant(color, 25) for color in cm]
cm_edge = [color_variant(color, -50) for color in cm]
    
# Timeseries 
ts = df.index.get_level_values('datetime')

# Yearly Data
df_ts_y = dfg.reset_index().groupby(pd.Grouper(freq='1A',key='datetime')).sum()

# Monthly Data
df_ts_m = dfg.reset_index().groupby(pd.Grouper(freq='1M',key='datetime')).sum()

# %%
month_offset = 1 - int(any([ts.max().is_month_end, ts.max() > pd.to_datetime('2015-12-23')]))

# Override Month 
# month_offset = 8

month_max = df_ts_m.ix[-(1 + month_offset),:].name.strftime("%B")

h2_success('Latest Results : %s' % month_max)
h3_info('Collected Food by Grouping')

latest_month = df_ts_m.ix[-(1 + month_offset),:]
prev_month = df_ts_m.ix[-(2 + month_offset),:]

x = pd.Index(latest_month.index.values)
y = latest_month.values

with sns.plotting_context("poster", font_scale=1, rc=c):
    plt.xlabel = 'xlabel'
    f, (ax) = plt.subplots()
    sns.barplot(x, y, palette=cm, x_order=x, ax=ax, edgecolor=cm_edge)
    ax.set_xlabel('FOOD CATEGORIES', labelpad=20)
    ax.set_ylabel('Collected (KG)', labelpad=20)
# Out:
# <h2 style="text-align:center" class="alert alert-success">Latest Results : August</h2>
# <h3 style="text-align:center" class="alert alert-info">Collected Food by Grouping</h3>

# %%
h3_info('Month on Month Performance (Absolute)')

diff_month = latest_month - prev_month
delta_month = pd.concat([latest_month, prev_month, diff_month], axis=1).astype('int')

l = ts.max().strftime('%b')
p = (ts.max() - pd.DateOffset(months=1)).strftime('%b')
d = 'Δ'

delta_month.columns = [l,p,d]
    
with sns.plotting_context("poster", font_scale=1, rc=c):
    sns.heatmap(delta_month.T, annot=True, fmt="d", cmap='RdBu', cbar=False);
#     plt.xlabel = 'xlabel'
#     f, (ax) = plt.subplots()
#     sns.barplot(x, y, palette='PuBu', x_order=x, ax=ax);
#     ax.set_xlabel('FOOD CATEGORIES', labelpad=20)
#     ax.set_ylabel('Collected (KG)', labelpad=20)
# Out:
# <h3 style="text-align:center" class="alert alert-info">Month on Month Performance (Absolute)</h3>

# %%
h3_info('Month on Month Performance (Relative)')

n1 = (latest_month / prev_month * 100).fillna(0).astype('int')
n2 = (prev_month/prev_month * 100).fillna(0).astype('int')
n3 = n1 - n2
idx_month = pd.concat([n1,n2,n3],axis=1)
idx_month.columns = [l,p,d]

with sns.plotting_context("poster", font_scale=1, rc=c):
    sns.heatmap(idx_month.T, annot=True, fmt="d", cmap='RdBu', cbar=False);
#     plt.xlabel = 'xlabel'
#     f, (ax) = plt.subplots()
#     sns.barplot(x, y, palette='PuBu', x_order=x, ax=ax);
#     ax.set_xlabel('FOOD CATEGORIES', labelpad=20)
#     ax.set_ylabel('Collected (KG)', labelpad=20)
# Out:
# <h3 style="text-align:center" class="alert alert-info">Month on Month Performance (Relative)</h3>

# %%
year_max = ts.max().strftime("%Y")

# Override Year 
# year_max = 2014

h2_success("Current Year : %s" % year_max)
# Out:
# <h2 style="text-align:center" class="alert alert-success">Current Year : 2015</h2>

# %%
h3_info('Monthly Breakdown')

cy = str(int(datetime.now().strftime('%Y')))
# Override Year
# cy =' 2014'
current_year = dfg.reset_index().ix[:,3:].set_index('datetime').ix[cy,:]

cy_gby_m = df_ts_m.ix[cy]
month_names = [x.strftime('%b') for x in pd.to_datetime(cy_gby_m.index)]
months_index = pd.Index([int(x.strftime('%m')) for x in pd.to_datetime(cy_gby_m.index)])

handles = []
stacked_bar_data = cy_gby_m.ix[:,::-1].cumsum(axis=1)
with sns.plotting_context("poster", font_scale=1, rc=c):
    f, (ax) = plt.subplots()
    for idx, category in enumerate(stacked_bar_data.columns.values[::-1]):
        sns.barplot(x = months_index, y = stacked_bar_data[category], color = cm[idx],
            edgecolor=cm_outline[idx]).set_ylabel('')
        handles.append(plt.Rectangle((0,0),1,1,fc=cm[idx], edgecolor = color_variant(cm[idx],50)))
        ax.set_xlabel('MONTHS', labelpad=20)
        ax.set_ylabel('Collected (KG)', labelpad=20)
        ax.set_xticklabels(month_names)

l = plt.legend(handles, list(stacked_bar_data.columns.values[::-1]), loc=1, ncol = 2, prop={'size':16})
sns.despine();
# Out:
# <h3 style="text-align:center" class="alert alert-info">Monthly Breakdown</h3>

# %%
h3_info('Weekly Pattern (Average)')

current_year['wkday'] = current_year.reset_index().datetime.dt.weekday.values
wkday_grouped = current_year.groupby('wkday')
weekly_mean = wkday_grouped.mean()
weekly_median = wkday_grouped.median()
weekdays = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']

handles = []
stacked_bar_data = weekly_mean.ix[:,::-1].cumsum(axis=1)
with sns.plotting_context("poster", font_scale=1, rc=c):
    f, (ax) = plt.subplots()
    for idx, category in enumerate(stacked_bar_data.columns.values[::-1]):
        
        sns.barplot(x = weekly_mean.index, y = stacked_bar_data[category], color = cm[idx],
            edgecolor=cm_outline[idx]).set_ylabel('')
        
        handles.append(plt.Rectangle((0,0),1,1,fc=cm[idx], edgecolor = color_variant(cm[idx],50)))
        ax.set_xlabel('WEEKDAYS', labelpad=20)
        ax.set_ylabel('Collected (KG)', labelpad=20)
        ax.set_xticklabels(weekdays)
        
l = plt.legend(handles, list(stacked_bar_data.columns.values[::-1]), loc=1, ncol = 2, prop={'size':16})
# Out:
# <h3 style="text-align:center" class="alert alert-info">Weekly Pattern (Average)</h3>

# %%
h3_info('Weekly Pattern (Expected)')

handles = []
stacked_bar_data = weekly_median.ix[:,::-1].cumsum(axis=1)
with sns.plotting_context("poster", font_scale=1, rc=c):
    f, (ax) = plt.subplots()
    for idx, category in enumerate(stacked_bar_data.columns.values[::-1]):
        sns.barplot(x = weekly_median.index, y = stacked_bar_data[category], color = cm[idx],
            edgecolor=cm_outline[idx]).set_ylabel('')
        
        handles.append(plt.Rectangle((0,0),1,1,fc=cm[idx], edgecolor = color_variant(cm[idx],50)))
        
        ax.set_xlabel('WEEKDAYS', labelpad=20)
        ax.set_ylabel('Collected (KG)', labelpad=20)
        ax.set_xticklabels(weekdays)
        
l = plt.legend(handles, list(stacked_bar_data.columns.values[::-1]), loc=1, ncol = 2, prop={'size':16})
# Out:
# <h3 style="text-align:center" class="alert alert-info">Weekly Pattern (Expected)</h3>

# %%
year_min = ts.min().strftime("%Y")
h2_success("Historic : %s - %s" % (year_min, year_max))
# Out:
# <h2 style="text-align:center" class="alert alert-success">Historic : 2014 - 2015</h2>

# %%
h3_info('Top 5 Stories')
df_unstack = df.T.unstack()
df_unstack.sort(ascending=False)
vimx = pd.DataFrame(df_unstack[:5]).reset_index().ix[:,3:]
vimx.columns = ['When','What','How Much']
table(vimx,print_header=True, print_index=False);
# Out:
# <h3 style="text-align:center" class="alert alert-info">Top 5 Stories</h3>
# <table class="table table-striped table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th>When</th>
#       <th>What</th>
#       <th>How Much</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2014-08-25</td>
#       <td>肉</td>
#       <td>8000.00</td>
#     </tr>
#     <tr>
#       <td>2014-10-22</td>
#       <td>鴻福堂</td>
#       <td>2355.00</td>
#     </tr>
#     <tr>
#       <td>2014-08-07</td>
#       <td>乾糧</td>
#       <td>2000.00</td>
#     </tr>
#     <tr>
#       <td>2015-08-26</td>
#       <td>飲品</td>
#       <td>1950.00</td>
#     </tr>
#     <tr>
#       <td>2015-05-06</td>
#       <td>飲品</td>
#       <td>1795.84</td>
#     </tr>
#   </tbody>
# </table>

# %%
h3_info('Monthly Food Recovery')

xticks = tuple([dt.strftime('%b `%y') for idx, dt in enumerate(df_ts_m.index) if not idx % 2])

with sns.plotting_context("poster", font_scale=1, rc=c):
    f, (ax) = plt.subplots()
    plt.plot(df_ts_m.sum(axis=1))
    ax.set_xticklabels(xticks)
    ax.set_xlabel('MONTHS', labelpad=20)
    ax.set_ylabel('Collected (KG)', labelpad=20)
# Out:
# <h3 style="text-align:center" class="alert alert-info">Monthly Food Recovery</h3>

# %%
# h3_info('Yearly Performance (Current)')

# handles = []
# stacked_bar_data = df_ts_y.ix[:,::-1].cumsum(axis=1)
# with sns.plotting_context("poster", font_scale=1, rc=dict(c,**{'figure.figsize': (18,10)})):
#     f, (ax) = plt.subplots()
#     for idx, category in enumerate(stacked_bar_data.columns.values[::-1]):
#         sns.barplot(x = pd.Index([2014]), y = stacked_bar_data[category], color = cm[idx],
#             edgecolor=cm_outline[idx]).set_ylabel('')
        
#         handles.append(plt.Rectangle((0,0),1,1, fc=cm[idx], edgecolor = color_variant(cm[idx],50)))
        
#         ax.set_xlabel('YEARS', labelpad=20)
#         ax.set_ylabel('Collected (KG)', labelpad=20)
#         ax.set_ylim([0,80000])


        
# l = plt.legend(handles, list(stacked_bar_data.columns.values[::-1]), loc=9, ncol = 3, prop={'size':16}, fancybox=True, framealpha=.7)
# l.draw_frame(True)

# %%
# h3_info('Yearly Performance (Predicted)')

# NOT YET AVAILABLE SINCE YEARLY CYCLE HAS NOT BEEN COMPLETE

# handles = []
# stacked_bar_data = df_ts_y.cumsum(axis=1)
# with sns.plotting_context("poster", font_scale=1, rc=c):
#     for idx, category in enumerate(stacked_bar_data.columns.values[::-1]):
#         sns.barplot(x = pd.Index([2014,2015]), y = stacked_bar_data[category], color = cm[idx]).set_ylabel('')
#         handles.append(plt.Rectangle((0,0),1,1,fc=cm[idx], edgecolor = 'none'))
        
# l = plt.legend(handles, list(stacked_bar_data.columns.values[::-1]), loc=1, ncol = 2, prop={'size':16})

# %%
HTML('''<a class='btn btn-warning btn-lg' style="margin:0 auto; display:block; max-width:320px" href="javascript:code_toggle()">TOGGLE CODE</a>''')
# Out:
# <a class='btn btn-warning btn-lg' style="margin:0 auto; display:block; max-width:320px" href="javascript:code_toggle()">TOGGLE CODE</a>

# %%
HTML('''<link href='http://fonts.googleapis.com/css?family=Roboto|Open+Sans' rel='stylesheet' type='text/css'>
<style>
body #notebook {
    font-family : 'Open Sans','Source Sans Pro','Proxima Nova', sans-serif;
    line-height: 1.4em;
    font-size: 1.2em;
    padding: 0 32px;
    line-height: 1.8em;
}

#notebook h1,
#notebook h2,
#notebook h3,
#notebook h4,
#notebook h5 {
    font-family : 'Roboto','Source Sans Pro','Proxima Nova', sans-serif;
}


#notebook .panel-body {
  font-size: 1.1em;
  line-height: 1.6em;
}

#notebook .table,
#notebook .table th,
#notebook .table td,
#notebook .table tr {
    text-align : center;
    border: 0;
    font-size: 1.5rem;
    line-height: 2.2rem
}

#notebook div.output_subarea {
    max-width:100%;
}
</style>

<script>
$(function(){
    code_toggle()
})
</script>

''')
# Out:
# <link href='http://fonts.googleapis.com/css?family=Roboto|Open+Sans' rel='stylesheet' type='text/css'>
# <style>
# body #notebook {
#     font-family : 'Open Sans','Source Sans Pro','Proxima Nova', sans-serif;
#     line-height: 1.4em;
#     font-size: 1.2em;
#     padding: 0 32px;
#     line-height: 1.8em;
# }
#
# #notebook h1,
# #notebook h2,
# #notebook h3,
# #notebook h4,
# #notebook h5 {
#     font-family : 'Roboto','Source Sans Pro','Proxima Nova', sans-serif;
# }
#
#
# #notebook .panel-body {
#   font-size: 1.1em;
#   line-height: 1.6em;
# }
#
# #notebook .table,
# #notebook .table th,
# #notebook .table td,
# #notebook .table tr {
#     text-align : center;
#     border: 0;
#     font-size: 1.5rem;
#     line-height: 2.2rem
# }
#
# #notebook div.output_subarea {
#     max-width:100%;
# }
# </style>
#
# <script>
# $(function(){
#     code_toggle()
# })
# </script>
